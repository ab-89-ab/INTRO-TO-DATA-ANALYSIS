# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('~/Desktop/Excel/Fortune-500.csv')

# %%
df.columns
# Out:
# Index(['Rank', 'Company Name', 'Number of Employees', 'Change in \nRank',
#        '2018 Revenues\n($millions)', 'Revenue  change from 2017\nChange',
#        ' 2018 Profits\n($millions)', 'Profit  change from 2017\nChange',
#        'Assets\n($millions)', 'Market Value \nAs of 3/29/19 ($m)'],
#       dtype='object')

# %%
df
# Out:
#      Rank          Company Name Number of Employees Change in \nRank  \
# 0       1               Walmart           2,200,000                -
# 1       2           Exxon Mobil              71,000                -
# 2       3                 Apple             132,000               1
# 3       4    Berkshire Hathaway             389,000              -1
# 4       5            Amazon.com             647,500               3
# ..    ...                   ...                 ...              ...
# 495   496  Simon Property Group               4,150              -3
# 496   497               Navient               6,500                -
# 497   498         Western Union              12,000              -4
# 498   499        Peabody Energy               7,400              -8
# 499   500          Levi Strauss              15,100                -
#
#     2018 Revenues\n($millions) Revenue  change from 2017\nChange  \
# 0                     $514,405                              2.8%
# ...
